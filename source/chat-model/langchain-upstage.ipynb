# %%
# 패키지 설치
# %pip install -U python-dotenv langchain-upstage
# Out:
# ...
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#    ---------------------------------------- 2.4/2.4 MB 26.2 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/566.4 kB ? eta -:--:--
#    --------------------------------------- 566.4/566.4 kB 18.4 MB/s eta 0:00:00
# ...
#
#    ---------------------------------------- 0/6 [pypdf]
#    ------ --------------------------------- 1/6 [fsspec]
#    ------------- -------------------------- 2/6 [filelock]
#    -------------------- ------------------- 3/6 [huggingface-hub]
#    -------------------- ------------------- 3/6 [huggingface-hub]
#    -------------------- ------------------- 3/6 [huggingface-hub]
#    --------------------------------- ------ 5/6 [langchain-upstage]
#    ---------------------------------------- 6/6 [langchain-upstage]
#
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 26.1.2
# ...

# %%
# 환경변수 Load
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
# LangChain기반 LLM 설정
from langchain_upstage import ChatUpstage

#llm = ChatUpstage(model="solar-pro3")
llm = ChatUpstage()

# %%
llm
# Out:
# ChatUpstage(output_version=None, client=<openai.resources.chat.completions.completions.Completions object at 0x0000020E56529D10>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x0000020E5652A710>, root_client=<openai.OpenAI object at 0x0000020E56529090>, root_async_client=<openai.AsyncOpenAI object at 0x0000020E56529E50>, model_name='solar-pro3', model_kwargs={}, openai_proxy=None, stream_chunk_timeout=120.0, disabled_params={'parallel_tool_calls': None}, upstage_api_key=SecretStr('**********'), upstage_api_base='https://api.upstage.ai/v1/solar')

# %%
# LLM 호출
ai_msg = llm.invoke("대한민국 정부가 세워진 날은 언제인가요?")

# %%
# 출력 확인
ai_msg
# Out:
# AIMessage(content='대한민국 정부가 공식적으로 수립된 날은 **1948년\u202f8월\u202f15일**입니다.  \n\n이날은 제헌 국회가 제정한 헌법에 따라 대한민국이 ‘대한민국 정부’를 수립하고, 초대 대통령으로 이승만(李承晩)이 취임하면서 국가의 정부 체제가 출범한 기념일로, 매년 **광복절**과 함께 ‘정부수립 기념일’로도 기념됩니다.  \n\n(참고: 1948년\u202f5월\u202f10일에 제헌 국회가 열리고, 7월\u202f17일에 헌법이 공포·발효되었으며, 그 후 8월\u202f15일에 정식 정부가 발족했습니다.)', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 122, 'prompt_tokens': 76, 'total_tokens': 198, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 48}}, 'model_provider': 'openai', 'model_name': 'solar-pro3-260323', 'system_fingerprint': None, 'id': '985398ce-3ca3-42db-a770-1d198ea316c9', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e9da0-8009-79d0-af22-3a313cf15f70-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 76, 'output_tokens': 122, 'total_to
# ...

# %%
# 출력 확인(content만)
ai_msg.content
# Out:
# '대한민국 정부는 1948년 8월 15일에 세워졌습니다. 이 날은 한국이 일제 강점기에서 벗어나 독립을 선언하고, 이후 수립된 대한민국 정부가 공식적으로 출범한 날로 기념되고 있습니다. 따라서 1948년 8월 15일은 대한민국의 건국절로 간주되며, 매년 이 날을 광복절로 기념하고 있습니다.'
